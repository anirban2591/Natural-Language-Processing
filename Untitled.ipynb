# %%
import requests

# %%
import asyncio

# %%
#pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=07a58b221e866b7ea007bf3e1f522692893ab4a84bdd4c48fb7d747f1ffcadbd
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import urllib3

# %%
urllib3.disable_warnings()

# %%
from concurrent.futures import ThreadPoolExecutor

# %%
r_email_rest = []
from email.message import EmailMessage

# %%
class ActionSendEmail(Action):
    #Define action name
    def name(self):
        return 'action_send_email'
        

    def run(self, dispatcher, tracker, domain):
        #Get user's email id
        to_email = tracker.get_slot('emailid')

        #Get location and cuisines to put in the email
        loc = tracker.get_slot('location')
        cuisine = tracker.get_slot('cuisine')
        global r_email_rest
        email_rest_count = len(r_email_rest)
        #Construct the email 'subject' and the contents.
        r_email_subj = "Top " + str(email_rest_count) + " " + cuisine.capitalize() + " restaurants in " + str(loc).capitalize()
        r_email_msg = "Hello this is your personal Foodie assistant. As per your requirements, here are the " + r_email_subj + "." + "\n" + "\n" +"\n"
        rest_num = 0
        for restaurant in r_email_rest:
            rest_num +=1
            r_email_msg = r_email_msg + "Restaurant " + str(rest_num) +": " + str(restaurant['restaurant']['name'])+ " in " + str(restaurant['restaurant']['location']['address']) + " has been rated " + str(restaurant['restaurant']['user_rating']['aggregate_rating']) + ".The average budget for 2 people is: " + str(restaurant['restaurant']['average_cost_for_two']) + "\n" + "\n"

        #Open SMTP connection to Foodie's email id.
        s = smtplib.SMTP("smtp.gmail.com", 587)
        s.starttls()
        s.login("******@gmail.com", "**********")

        #Create the msg object
        msg = EmailMessage()

        #Fill in the message properties
        msg['Subject'] = r_email_subj
        msg['From'] = "*********@gmail.com"

        #Fill in the message content
        msg.set_content(r_email_msg)
        msg['To'] = to_email
        
        #Sent the message. If error catch and throw it
        try:
            s.send_message(msg)
            s.quit()
            dispatcher.utter_message("Email Sent. Please check your inbox. Have a great time!!")
        except (RuntimeError, TypeError, NameError, AttributeError):
            dispatcher.utter_message("Email server not responding at time")
        return []

#global function to retrieve restaurants from Zomato
def retrieve_restaurant(lat, lon, cuisines_dict, cuisine, res_key, r_rest):
    base_url = "https://developers.zomato.com/api/v2.1/"
    headers = {'Accept': 'application/json',
                'user-key': '**********'}
    try:
        results = (requests.get(base_url + "search?" + "&lat=" + str(lat) + "&lon=" + str(lon) + "&cuisines=" + str(
            cuisines_dict.get(cuisine)) + "&start=" + str(res_key)+"&count=20", headers=headers).content).decode("utf-8")
    except:
        return
    d = json.loads(results)
    r_rest.extend(d['restaurants'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35047966f455> in <module>
# ----> 1 class ActionSendEmail(Action):
#       2     #Define action name
#       3     def name(self):
#       4         return 'action_send_email'
#       5
#
# NameError: name 'Action' is not defined

# %%
to_email = tracker.get_slot('emailid')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a0c487e9381> in <module>
# ----> 1 to_email = tracker.get_slot('emailid')
#
# NameError: name 'tracker' is not defined

# %%
class VerifyLocation(Action):
    #Define action
    def name(self):
        return "action_verify_location"
    
    def run(self, dispatcher, tracker, domain): 
        #Extract the list of tier 1 and 2 cities from wikipage
        url="https://en.wikipedia.org/wiki/Classification_of_Indian_cities"
        r = requests.get(url,verify=False)
        soup = BeautifulSoup(r.text, "html.parser")
    
        #Parse the content to extract names
        cities=list(map(lambda x:x.text.lower(),soup.find('table',class_='wikitable').find_all('a')))
        
        #Get the list of common synonym names for the cities in tier 1 and 2
        city_synonym=[]
        #Extract the common city synonyms from this page
        r=requests.get('https://www.scoopwhoop.com/news/whats-in-a-name/#.45rdcz1m2',verify=False)
        synonym_list=BeautifulSoup(r.text,'html.parser').find('div',class_='article-body').find_all('h2')
        
        #extract Synonym list
        for city in synonym_list:
            if re.search(r'^[0-9]{1,2}.+',city.text.strip()):
                city_synonym.append(city.text.strip().split()[1].lower())
                city_synonym.append(city.text.strip().split()[-1].lower())        
        
        #Few other city synonyms as gathered from the internet
        city_synonym_2 = ['allahabad','atal-nagar','bangalore','baroda','bejawada ','belagavi ','belgaum','benares','bengaluru',
                        'bijapur','bombay','calcutta ','calicut','cannanore','cawnpore ','chennai','cochin','gauhati',
                        'gulbarga ','gurgaon','gurugram ','guwahati ','hubballi ','hubli ','indhur','indore','jabalpur ',
                        'jajesmow ','jajmau','jubbulpore ','kalaburagi ','kannur','kanpur','kochi ','kolkata','kollam',
                        'kozhikode','kudanthai','kumbakonam ','madras','mangalore','mangaluru','mumbai','bombay','mysore','mysore',
                        'mysuru','nellore','panaji','panjim','pondicherry','poona ','prayagraj','puducherry ','pune',
                        'quilon','raipur','shimla','simhapuri','simla ','thiruvananthapuram','thrissur ','tindivanam ',
                        'tinnevelly ','tinthirivanam ','tiruchirapalli','tirunelveli','tiruvallikeni ','trichinopoly',
                        'trichur','triplicane ','trivandrum ','vadodara ','varanasi ','vatakara ','vijayapura ','vijayawada ',
                        'visakhapatnam ','waltair']
        
        #List of all valid cities in India for verification. Parse from this page
        url1="https://en.wikipedia.org/wiki/List_of_cities_in_India_by_population"
        r1 = requests.get(url1,verify=False)
        soup1 = BeautifulSoup(r1.text, "html.parser")
        
        #Extract list of all cities in India
        all_cities_list = []
        temp_city=list(map(lambda x:x.text.lower(),soup1.find('table',class_='wikitable').find_all('a')))
        for city in temp_city:
            if not re.search(r'^.[0-9]{1,2}.+',city):
                all_cities_list.append(city)

        #get the location from user slot
        loc=tracker.get_slot('location')
        
        #Check for pincodes. Not supported for now
        if (loc.lower().isdigit()):
            dispatcher.utter_message("Sorry I am naive I dont understand pincodes and digits for now. Please try some actual place!!")
            return [SlotSet('location', None), SlotSet("location_ok", False)]
        #Check for invalid city
        elif not (loc.lower() in all_cities_list  or loc.lower() in city_synonym or loc.lower() in city_synonym_2 or loc.lower() in cities):
            dispatcher.utter_message("Sorry did'nt find any such location " + loc + " Can you please tell again?")
            return [SlotSet('location', None), SlotSet("location_ok", False)]
        #Check for valid city but no servicable by Zomato
        elif not (loc.lower() in city_synonym or loc.lower() in city_synonym_2 or loc.lower() in cities):
            dispatcher.utter_message("We do not operate in " + loc + " yet. Please try some other city.")
            return [SlotSet('location', None), SlotSet("location_ok", False)]
        #If valid city and servicable return true
        else:
            return [SlotSet('location',loc),SlotSet('location_ok',True)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4505a587801d> in <module>
# ----> 1 class VerifyLocation(Action):
#       2     #Define action
#       3     def name(self):
#       4         return "action_verify_location"
#       5
#
# NameError: name 'Action' is not defined

# %%
import zomatopy
import json
import smtplib
from email.message import EmailMessage

# %%
config={ "user_key":"d7d2afaf2f19d43708fb09bbe480d6b0"}

# %%
zomato = zomatopy.initialize_app(config)

# %%
loc = 'kolkata'
cuisine = 'american'
price = 400

# %%
location_detail=zomato.get_location(loc, 1)
print(location_detail)
# Out:
# {"location_suggestions":[{"entity_type":"city","entity_id":2,"title":"Kolkata","latitude":22.572646,"longitude":88.363895,"city_id":2,"city_name":"Kolkata","country_id":1,"country_name":"India"}],"status":"success","has_more":0,"has_total":0,"user_has_addresses":true}

# %%
d1 = json.loads(location_detail)
lat=d1["location_suggestions"][0]["latitude"]
lon=d1["location_suggestions"][0]["longitude"]
cuisines_dict={'bakery':5, 'american':1, 'mexican':73, 'chinese':25,'cafe':30,'italian':55,'biryani':7,'north indian':50,'south indian':85}
results=zomato.restaurant_search("", lat, lon, str(cuisines_dict.get(cuisine)), 50)

# %%
import pprint
json_results = json.loads(results)
json_results
# Out:
# {'results_found': 699,
#  'results_start': 0,
#  'results_shown': 20,
#  'restaurants': [{'restaurant': {'R': {'res_id': 25679,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '25679',
#     'name': 'The Wise Owl Steakhouse',
#     'url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Rooftop, 66/2B, Purna Das Road, Hindustan Park, Kolkata',
#      'locality': 'Hindustan Park',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5170705000',
#      'longitude': '88.3609965000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Hindustan Park, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Steak, American, Italian',
#     'timings': '1:30 PM to 11 PM',
#     'average_cost_for_two': 1000,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Dinner',
#      'Debit Card',
#      'Lunch',
#      'Takeaway Available',
#      'Cash',
#      'Table booking recommended',
#      'Outdoor Seating',
#      'Smoking Area',
#      'Rooftop'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/9/25679/899bc06f0230b838c356f540e565403f.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1465},
#     'all_reviews_count': 504,
#     'photos_url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1220,
#     'menu_url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/9/25679/899bc06f0230b838c356f540e565403f.jpg',
#     'medio_provider': True,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/25679',
#     'order_url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/kolkata/the-wise-owl-steakhouse-hindustan-park/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9830630960, 033 40637038',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 23848,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '23848',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-hatibagan?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '138/2, Bidhan Sarani, Hatibagan, Kolkata',
#      'locality': 'Hatibagan',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5960934396',
#      'longitude': '88.3713026717',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Hatibagan, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 1 AM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Cash',
#      'Delivery',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Dinner',
#      'Indoor Seating',
#      'Axis Bank - Dining Delights',
#      'Air Conditioned',
#      'Sodexo',
#      'Table Reservation Not Required'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 5624},
#     'all_reviews_count': 369,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-hatibagan/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 423,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-hatibagan/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/23848',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-hatibagan/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-hatibagan/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 24432,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '24432',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-tollygunge?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '123/3, N.S.C. Bose Road, Netaji Nagar, Tollygunge, Kolkata',
#      'locality': 'Tollygunge',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.4797976259',
#      'longitude': '88.3561414853',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Tollygunge, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Dinner',
#      'Cash',
#      'Axis Bank - Dining Delights',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Sodexo'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 5956},
#     'all_reviews_count': 317,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-tollygunge/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 297,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-tollygunge/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/24432',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-tollygunge/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-tollygunge/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 21366,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '21366',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-sector-1-salt-lake?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Unit 106, City Center, Block DC, Plot I, Sector 1, Salt Lake, Kolkata',
#      'locality': 'City Centre 1, Sector 1, Salt Lake',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5880272326',
#      'longitude': '88.4081485122',
#      'zipcode': '700064',
#      'country_id': 1,
#      'locality_verbose': 'City Centre 1, Sector 1, Salt Lake, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Cash',
#      'Mall Parking',
#      'Takeaway Available',
#      'Credit Card',
#      'No Alcohol Available',
#      'Debit Card',
#      'Dinner',
#      'Lunch',
#      'Table booking recommended',
#      'Axis Bank - Dining Delights',
#      'Air Conditioned',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.8',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.8'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 3992},
#     'all_reviews_count': 548,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-1-salt-lake/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 726,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-1-salt-lake/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/21366',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-1-salt-lake/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-1-salt-lake/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18895600,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18895600',
#     'name': 'Forkstruck',
#     'url': 'https://www.zomato.com/kolkata/forkstruck-lake-gardens?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '188/13, Jodhpur Garden, Lake Gardens, Kolkata',
#      'locality': 'Lake Gardens',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5031486877',
#      'longitude': '88.3582138270',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Lake Gardens, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, Salad, American',
#     'timings': '12noon – 2am (Mon-Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Takeaway Available',
#      'Lunch',
#      'Cash',
#      'Delivery',
#      'Dinner',
#      'Free Parking',
#      'Digital Payments Accepted',
#      'Wifi',
#      'Vegan Options',
#      'Outdoor Seating',
#      'Air Conditioned',
#      'Smoking Area'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/18895600/d0acf08b68ed4ec29fa3c3f5d250bee8.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1915},
#     'all_reviews_count': 130,
#     'photos_url': 'https://www.zomato.com/kolkata/forkstruck-lake-gardens/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 174,
#     'menu_url': 'https://www.zomato.com/kolkata/forkstruck-lake-gardens/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/18895600/d0acf08b68ed4ec29fa3c3f5d250bee8.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18895600',
#     'order_url': 'https://www.zomato.com/kolkata/forkstruck-lake-gardens/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/forkstruck-lake-gardens/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 6290033534',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 22259,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '22259',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-shibpur-howrah?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '32, 3rd Floor, Avani Riverside Mall, Jagat Banerjee Ghat Road, Shibpur, Howrah',
#      'locality': 'Avani Riverside Mall, Shibpur',
#      'city': 'Howrah',
#      'city_id': 2,
#      'latitude': '22.5632845755',
#      'longitude': '88.3235318586',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Avani Riverside Mall, Shibpur, Howrah'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Delivery',
#      'Cash',
#      'Credit Card',
#      'Mall Parking',
#      'Debit Card',
#      'Lunch',
#      'Sodexo',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Wheelchair Accessible'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2256},
#     'all_reviews_count': 257,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-shibpur-howrah/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 410,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-shibpur-howrah/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/22259',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-shibpur-howrah/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-shibpur-howrah/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18503564,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18503564',
#     'name': 'The Bahubelly',
#     'url': 'https://www.zomato.com/kolkata/the-bahubelly-1-kadamtala-howrah?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '67, Natabar Paul Road, Tikiapara, Kadamtala, Howrah',
#      'locality': 'Kadamtala',
#      'city': 'Howrah',
#      'city_id': 2,
#      'latitude': '22.5936000000',
#      'longitude': '88.3194380000',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kadamtala, Howrah'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Fast Food, American, Burger, Sandwich',
#     'timings': '9am – 12midnight (Mon-Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Takeaway Available',
#      'Cash',
#      'Seating Available',
#      'Dinner',
#      'Lunch',
#      'Debit Card',
#      'Breakfast',
#      'Digital Payments Accepted',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/19294348/8bdb416f925145b9283038158a2a3a64.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 12352},
#     'all_reviews_count': 189,
#     'photos_url': 'https://www.zomato.com/kolkata/the-bahubelly-1-kadamtala-howrah/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 123,
#     'menu_url': 'https://www.zomato.com/kolkata/the-bahubelly-1-kadamtala-howrah/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/19294348/8bdb416f925145b9283038158a2a3a64.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18503564',
#     'order_url': 'https://www.zomato.com/kolkata/the-bahubelly-1-kadamtala-howrah/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/the-bahubelly-1-kadamtala-howrah/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8017184728',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 23822,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '23822',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-ballygunge?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '4th Floor, Quest Mall, 33, Syed Ali Amir Avenue, Ballygunge, Kolkata',
#      'locality': 'Quest Mall, Ballygunge',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5385548194',
#      'longitude': '88.3652723953',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Quest Mall, Ballygunge, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Cash',
#      'Debit Card',
#      'Mall Parking',
#      'Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Credit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Axis Bank - Dining Delights'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 4722},
#     'all_reviews_count': 265,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-ballygunge/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 251,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-ballygunge/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/23822',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-ballygunge/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-ballygunge/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Food Court'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 21370,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': -1, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '21370',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-chinar-park?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Ground Floor, City Centre 2 Mall, Chinar Park, Kolkata',
#      'locality': 'City Centre 2 Mall, Chinar Park',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.6229745968',
#      'longitude': '88.4503664821',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'City Centre 2 Mall, Chinar Park, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Lunch',
#      'Credit Card',
#      'Takeaway Available',
#      'Cash',
#      'Dinner',
#      'No Alcohol Available',
#      'Debit Card',
#      'Mall Parking',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Sodexo',
#      'Table Reservation Not Required'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 743},
#     'all_reviews_count': 324,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-chinar-park/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 544,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-chinar-park/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/21370',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-chinar-park/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '033 40010876',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18519249,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18519249',
#     'name': 'Kolkata Fried Chicken',
#     'url': 'https://www.zomato.com/kolkata/kolkata-fried-chicken-shibpur-howrah?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '290, Grand Trunk Road, Naora, Shibpur, Howrah',
#      'locality': 'Shibpur',
#      'city': 'Howrah',
#      'city_id': 2,
#      'latitude': '22.5639600000',
#      'longitude': '88.3204200000',
#      'zipcode': '711102',
#      'country_id': 1,
#      'locality_verbose': 'Shibpur, Howrah'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, American, Fast Food, Street Food, Sandwich, Wraps',
#     'timings': '10am – 11pm (Mon-Sun)',
#     'average_cost_for_two': 350,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Delivery',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Cash',
#      'Takeaway Available',
#      'Breakfast',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/9/18519249/cbf75e9ddf82bf0467b7709dcf62b7a8.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.1',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.1'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 15264},
#     'all_reviews_count': 386,
#     'photos_url': 'https://www.zomato.com/kolkata/kolkata-fried-chicken-shibpur-howrah/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 65,
#     'menu_url': 'https://www.zomato.com/kolkata/kolkata-fried-chicken-shibpur-howrah/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/9/18519249/cbf75e9ddf82bf0467b7709dcf62b7a8.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18519249',
#     'order_url': 'https://www.zomato.com/kolkata/kolkata-fried-chicken-shibpur-howrah/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/kolkata-fried-chicken-shibpur-howrah/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 6289805755, +91 7003949340',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18929239,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18929239',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-uttarpara?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '20 & 22B, Unimark Riviera, Bhadrakali, Near GT Road Uttarpara, Uttarpara, Kolkata',
#      'locality': 'Uttarpara',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.6745348954',
#      'longitude': '88.3518807963',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Uttarpara, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11am – 1am (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Credit Card',
#      'Cash',
#      'Debit Card',
#      'Delivery',
#      'Digital Payments Accepted',
#      'Air Conditioned',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 3941},
#     'all_reviews_count': 123,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-uttarpara/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 76,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-uttarpara/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18929239',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-uttarpara/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-uttarpara/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9874289555',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19221192,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '19221192',
#     'name': 'The Bahubelly',
#     'url': 'https://www.zomato.com/kolkata/the-bahubelly-kankurgachi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '17, Bagmari Lane, Manicktala, BRS 10, Kankurgachi, Kolkata',
#      'locality': 'Kankurgachi',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5823006138',
#      'longitude': '88.3917169645',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Kankurgachi, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Fast Food, American, Burger, Sandwich',
#     'timings': '11am – 3am (Mon-Sat),9am – 12midnight (Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Takeaway Available',
#      'Debit Card',
#      'Seating Available',
#      'Lunch',
#      'Dinner',
#      'Cash',
#      'Air Conditioned',
#      'Digital Payments Accepted',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/19294348/8bdb416f925145b9283038158a2a3a64.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 6892},
#     'all_reviews_count': 128,
#     'photos_url': 'https://www.zomato.com/kolkata/the-bahubelly-kankurgachi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 12,
#     'menu_url': 'https://www.zomato.com/kolkata/the-bahubelly-kankurgachi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/19294348/8bdb416f925145b9283038158a2a3a64.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19221192',
#     'order_url': 'https://www.zomato.com/kolkata/the-bahubelly-kankurgachi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/the-bahubelly-kankurgachi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9836166105',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 24909,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '24909',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-sector-4-salt-lake?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Near Nicco Park, Sector 4, Salt Lake, Kolkata',
#      'locality': 'Sector 4, Salt Lake',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5729475635',
#      'longitude': '88.4214358404',
#      'zipcode': '700106',
#      'country_id': 1,
#      'locality_verbose': 'Sector 4, Salt Lake, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 1 AM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Credit Card',
#      'Delivery',
#      'No Alcohol Available',
#      'Lunch',
#      'Cash',
#      'Debit Card',
#      'Takeaway Available',
#      'Dinner',
#      'Indoor Seating',
#      'Table booking not available',
#      'Air Conditioned',
#      'Axis Bank - Dining Delights'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 5102},
#     'all_reviews_count': 207,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-4-salt-lake/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 201,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-4-salt-lake/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/24909',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-4-salt-lake/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-sector-4-salt-lake/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18900259,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18900259',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-2-barasat?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '74/1, Jessore Road, Udayrajpur, Madhyamgram Municipality, Barasat, Kolkata',
#      'locality': 'Barasat',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.7036867335',
#      'longitude': '88.4719210491',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Barasat, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Cash',
#      'Debit Card',
#      'Dinner',
#      'Lunch',
#      'Takeaway Available',
#      'Air Conditioned',
#      'Indoor Seating',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2181},
#     'all_reviews_count': 84,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-2-barasat/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 91,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-2-barasat/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18900259',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-2-barasat/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-2-barasat/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 24338,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '24338',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-kankurgachi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '3rd Floor, Mani Square Mall, 164/1, E.M. Bypass, Kankurgachi, Kolkata',
#      'locality': 'Mani Square Mall, Kankurgachi',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5778102258',
#      'longitude': '88.4002031386',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Mani Square Mall, Kankurgachi, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Takeaway Available',
#      'Cash',
#      'Mall Parking',
#      'Dinner',
#      'No Alcohol Available',
#      'Lunch',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Sodexo',
#      'Axis Bank - Dining Delights'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 720},
#     'all_reviews_count': 172,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-kankurgachi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 219,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-kankurgachi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/24338',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-kankurgachi/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-kankurgachi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Food Court'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 24981,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '24981',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-howrah-station-area-howrah?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Ground Floor, Howrah Rail Yatri Niwas, New Complex, Howrah Railway Station, Howrah',
#      'locality': 'Howrah Station Area',
#      'city': 'Howrah',
#      'city_id': 2,
#      'latitude': '22.5815610487',
#      'longitude': '88.3423814178',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Howrah Station Area, Howrah'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 11 PM (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Debit Card',
#      'Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Credit Card',
#      'Delivery',
#      'Sodexo',
#      'Indoor Seating',
#      'Air Conditioned'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 767},
#     'all_reviews_count': 101,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-howrah-station-area-howrah/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 98,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-howrah-station-area-howrah/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/24981',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-howrah-station-area-howrah/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-howrah-station-area-howrah/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18781464,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18781464',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-1-lake-market-area?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '104, 4th Floor, Lake Mall, Rashbehari Avenue, Lake Market Area, Kolkata',
#      'locality': 'Lake Market Area',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5165325478',
#      'longitude': '88.3488733694',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Lake Market Area, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11am – 1am (Mon-Sun)',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Cash',
#      'Debit Card',
#      'Lunch',
#      'Dinner',
#      'Takeaway Available',
#      'Air Conditioned',
#      'Indoor Seating',
#      'Sodexo',
#      'Axis Bank - Dining Delights',
#      'Kid Friendly'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 1073},
#     'all_reviews_count': 110,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-1-lake-market-area/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 107,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-1-lake-market-area/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18781464',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-1-lake-market-area/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-1-lake-market-area/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 19094888,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '19094888',
#     'name': 'Pizza Hut',
#     'url': 'https://www.zomato.com/kolkata/pizza-hut-1-park-street-area?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '20 K, Sir William Jones Sarani, Park Street Area, Kolkata',
#      'locality': 'Park Street Area',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5522266190',
#      'longitude': '88.3526033163',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Park Street Area, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Pizza, Fast Food, Finger Food, American',
#     'timings': '11 AM to 1 AM',
#     'average_cost_for_two': 600,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Dinner',
#      'Lunch',
#      'Cash',
#      'Air Conditioned',
#      'Indoor Seating',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2075},
#     'all_reviews_count': 118,
#     'photos_url': 'https://www.zomato.com/kolkata/pizza-hut-1-park-street-area/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 65,
#     'menu_url': 'https://www.zomato.com/kolkata/pizza-hut-1-park-street-area/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/20407/97e19c1e08d060fd6033c1bb420fd366.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19094888',
#     'order_url': 'https://www.zomato.com/kolkata/pizza-hut-1-park-street-area/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/pizza-hut-1-park-street-area/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '18002022022',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18685995,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18685995',
#     'name': 'The Chicken Xpress',
#     'url': 'https://www.zomato.com/kolkata/the-chicken-xpress-jadavpur?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '123/A, Anandapally, Jadavpur, Kolkata',
#      'locality': 'Jadavpur',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.4891108292',
#      'longitude': '88.3708919585',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Jadavpur, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Burger, American, Street Food',
#     'timings': '4:30 PM to 12 Midnight',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Cash',
#      'Dinner',
#      'No Seating Available',
#      'Takeaway Available'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/5/18685995/1a49c0fb39c74e23deb944266819577a.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 1573},
#     'all_reviews_count': 61,
#     'photos_url': 'https://www.zomato.com/kolkata/the-chicken-xpress-jadavpur/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 21,
#     'menu_url': 'https://www.zomato.com/kolkata/the-chicken-xpress-jadavpur/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/5/18685995/1a49c0fb39c74e23deb944266819577a.jpg?output-format=webp',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18685995',
#     'order_url': 'https://www.zomato.com/kolkata/the-chicken-xpress-jadavpur/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/kolkata/the-chicken-xpress-jadavpur/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9830569765',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'res_id': 18593946,
#      'is_grocery_store': False,
#      'has_menu_status': {'delivery': True, 'takeaway': -1}},
#     'apikey': 'd7d2afaf2f19d43708fb09bbe480d6b0',
#     'id': '18593946',
#     'name': 'The Fat Filler',
#     'url': 'https://www.zomato.com/the-fat-filler-food-truck?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '38 B, Raja Dinendra Street, Maniktala, Kolkata',
#      'locality': 'Maniktala',
#      'city': 'Kolkata',
#      'city_id': 2,
#      'latitude': '22.5844908051',
#      'longitude': '88.3769564331',
#      'zipcode': '700009',
#      'country_id': 1,
#      'locality_verbose': 'Maniktala, Kolkata'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Fast Food, American, Burger',
#     'timings': '11 AM to 11 PM (Mon-Thu), 11 AM to 2 AM (Fri-Sun)',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Dinner',
#      'Cash',
#      'No Seating Available',
#      'Lunch',
#      'Takeaway Available'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/ae8/e279f868195abf6c7a6af3d115764ae8_1524538869.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.2',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.2'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 343},
#     'all_reviews_count': 44,
#     'photos_url': 'https://www.zomato.com/the-fat-filler-food-truck/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 38,
#     'menu_url': 'https://www.zomato.com/the-fat-filler-food-truck/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/ae8/e279f868195abf6c7a6af3d115764ae8_1524538869.jpg',
#     'medio_provider': False,
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18593946',
#     'order_url': 'https://www.zomato.com/the-fat-filler-food-truck/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/the-fat-filler-food-truck/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9836123058, +91 8420755524',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}}]}

# %%
pprint?
